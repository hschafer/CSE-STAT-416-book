# %%
from pyforest import *

sns.set()
# %matplotlib inline

# %%
xs = np.random.rand(20)

def f(x):
    return 21 * x ** 3 - 37 * x ** 2 + 20 * x - 4

ys = f(xs) + np.random.normal(scale=0.5, size=len(xs))
ys

plt.scatter(xs, ys)

fine_xs = np.linspace(0, 1, 100)
plt.plot(fine_xs, f(fine_xs))

# %%
ys2 = (ys + 4) / 4
plt.scatter(xs, ys2)

def f(x):
    
    return (21 * x ** 3 - 37 * x ** 2 + 20 * x) 

fine_xs = np.linspace(0, 1, 100)
plt.plot(fine_xs, f(fine_xs))

# %%
xs * 4
# Out:
# array([3.16087855, 0.42209176, 0.10747032, 2.29757283, 2.41755141,
#        3.1312064 , 3.41274744, 0.54062515, 3.97612742, 3.88264967,
#        1.00726116, 2.48506019, 0.52647503, 2.78625823, 2.74012214,
#        2.6109622 , 0.99758877, 1.58532599, 3.68280559, 2.92428234])

# %%
from manimlib.imports import *

# %%
VGroup.__dict__
# Out:
# mappingproxy({'__module__': 'manimlib.mobject.types.vectorized_mobject',
#               '__init__': <function manimlib.mobject.types.vectorized_mobject.VGroup.__init__(self, *vmobjects, **kwargs)>,
#               '__doc__': None})
